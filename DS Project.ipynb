# %%
import pandas as pd

nse_df = pd.read_csv('../DS_Project_Dataset.csv', parse_dates=True, index_col = 10) #make timestamp as 1st col
nse_df.head()
#pd.rolling(2).mean(nse_df.set_index('CLOSE').groupby('SYMBOL')['TOTTRDVAL'],window=365,freq='D',min_periods=1)
nse_df[['CLOSE']].rolling(window=50).mean().plot()

# %%
nse_df.sort_values(by=['SYMBOL','TIMESTAMP']).head() #sort values
# Out:
#                SYMBOL SERIES   OPEN   HIGH     LOW   CLOSE    LAST  PREVCLOSE  \
# TIMESTAMP
# 2016-01-04  SUNPHARMA     EQ  813.9  821.3  795.10  799.10  797.80     815.55
# 2016-01-05  SUNPHARMA     EQ  807.0  807.0  792.05  800.50  800.75     799.10
# 2016-01-06  SUNPHARMA     EQ  805.0  805.8  790.75  791.95  791.45     800.50
# 2016-01-07  SUNPHARMA     EQ  788.0  799.0  778.65  783.80  786.70     791.95
# 2016-01-08  SUNPHARMA     EQ  795.0  805.8  786.00  794.15  792.20     783.80
#
#             TOTTRDQTY     TOTTRDVAL  TOTALTRADES          ISIN
# TIMESTAMP
# 2016-01-04    2388588  1.920584e+09        85014  INE044A01036
# 2016-01-05    1632394  1.306676e+09        73398  INE044A01036
# 2016-01-06    2168214  1.725307e+09        51865  INE044A01036
# 2016-01-07    2082334  1.635707e+09        49345  INE044A01036
# 2016-01-08    2315237  1.841919e+09        71528  INE044A01036

# %%
nse_df.drop_duplicates() #remove duplicate values
# Out:
#                 SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE  \
# TIMESTAMP
# 2017-06-28   20MICRONS     EQ     37.80     37.80     36.15     36.85
# 2017-06-28  3IINFOTECH     EQ      4.10      4.85      4.00      4.55
# 2017-06-28     3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70
# 2017-06-28     63MOONS     EQ     61.00     61.90     60.35     61.00
# 2017-06-28     8KMILES     EQ    546.10    548.00    535.00    537.45
# 2017-06-28    A2ZINFRA     EQ     41.30     43.00     41.25     42.00
# 2017-06-28  AARTIDRUGS     EQ    539.90    539.90    520.00    521.85
# 2017-06-28    AARTIIND     EQ    890.95    894.90    876.90    891.30
# 2017-06-28   AARVEEDEN     EQ     58.20     61.20     57.00     59.50
# 2017-06-28        ABAN     EQ    183.00    184.65    180.80    182.10
# 2017-06-28         ABB     EQ   1444.00   1459.70   1424.00   1452.00
# 2017-06-28  ABBOTINDIA     EQ   4300.00   4305.00   4230.00   4236.10
# ...

# %%
nse_df.loc[:, ['SYMBOL','CLOSE']]
# Out:
#                 SYMBOL     CLOSE
# TIMESTAMP
# 2017-06-28   20MICRONS     36.85
# 2017-06-28  3IINFOTECH      4.55
# 2017-06-28     3MINDIA  13266.70
# 2017-06-28     63MOONS     61.00
# 2017-06-28     8KMILES    537.45
# 2017-06-28    A2ZINFRA     42.00
# 2017-06-28  AARTIDRUGS    521.85
# 2017-06-28    AARTIIND    891.30
# 2017-06-28   AARVEEDEN     59.50
# 2017-06-28        ABAN    182.10
# 2017-06-28         ABB   1452.00
# 2017-06-28  ABBOTINDIA   4236.10
# 2017-06-28       ABFRL    166.55
# 2017-06-28     ABGSHIP     13.85
# 2017-06-28  ABIRLANUVO   1804.45
# 2017-06-28   ABMINTLTD     96.35
# 2017-06-28         ACC   1580.05
# 2017-06-28     ACCELYA   1331.00
# 2017-06-28         ACE     68.80
# 2017-06-28    ADANIENT    134.40
# 2017-06-28  ADANIPORTS    364.50
# 2017-06-28  ADANIPOWER     28.25
# 2017-06-28  ADANITRANS    123.25
# 2017-06-28    ADFFOODS    247.95
# 2017-06-28     ADHUNIK      5.80
# 2017-06-28  ADHUNIKIND    100.45
# 2017-06-28      ADLABS     76.75
# ...

# %%
nse_df[nse_df.SYMBOL == 'SUNPHARMA'].head()
# Out:
#                SYMBOL SERIES    OPEN    HIGH     LOW   CLOSE    LAST  \
# TIMESTAMP
# 2017-06-28  SUNPHARMA     EQ  543.80  548.15  538.00  545.45  546.00
# 2017-11-28  SUNPHARMA     EQ  551.00  556.35  541.10  543.15  542.30
# 2017-02-28  SUNPHARMA     EQ  675.00  682.30  675.00  679.00  679.00
# 2017-04-28  SUNPHARMA     EQ  637.25  644.20  637.25  641.95  642.90
# 2017-03-20  SUNPHARMA     EQ  709.00  711.00  704.50  706.55  706.45
#
#             PREVCLOSE  TOTTRDQTY     TOTTRDVAL  TOTALTRADES          ISIN
# TIMESTAMP
# 2017-06-28     544.05    5278948  2.873408e+09        50974  INE044A01036
# 2017-11-28     551.55    2493500  1.365450e+09        50197  INE044A01036
# 2017-02-28     674.45    2711558  1.841967e+09        43921  INE044A01036
# 2017-04-28     637.00    1903299  1.220218e+09        52213  INE044A01036
# 2017-03-20     707.50    1418664  1.003517e+09        25877  INE044A01036

# %%
col = nse_df.columns

col
# Out:
# Index(['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST', 'PREVCLOSE',
#        'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES', 'ISIN'],
#       dtype='object')

# %%
from pandas_datareader import data
import matplotlib.pyplot as plot
import datetime

# %%
import pandas as pd

sun_df = pd.read_csv('C:/Users/afara/Documents/DS Lab/sun.csv', parse_dates=True,index_col = 0 )
sun_df["CLOSE"].plot()

# %%
#sun_df.rolling(20,1,sun_df["CLOSE"])
sun_df.sort_index()
# Out:
#            SERIES    OPEN    HIGH     LOW   CLOSE    LAST  PREVCLOSE  \
# Date
# 2016-01-04     EQ  813.90  821.30  795.10  799.10  797.80     815.55
# 2016-01-05     EQ  807.00  807.00  792.05  800.50  800.75     799.10
# 2016-01-06     EQ  805.00  805.80  790.75  791.95  791.45     800.50
# 2016-01-07     EQ  788.00  799.00  778.65  783.80  786.70     791.95
# 2016-01-08     EQ  795.00  805.80  786.00  794.15  792.20     783.80
# 2016-01-11     EQ  789.50  804.50  779.10  782.25  784.00     794.15
# 2016-01-12     EQ  784.00  794.00  784.00  788.15  788.00     782.25
# 2016-01-13     EQ  795.00  804.65  781.50  796.60  799.75     788.15
# 2016-01-14     EQ  789.80  796.40  785.70  791.85  792.50     796.60
# 2016-01-15     EQ  797.75  799.00  780.20  787.10  790.90     791.85
# 2016-01-18     EQ  787.00  797.50  775.00  784.95  784.60     787.10
# 2016-01-19     EQ  786.00  796.80  781.25  793.90  793.90     784.95
# ...
